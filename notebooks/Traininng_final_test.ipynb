# %% [markdown]
# # Final Testing
# This notebook was uploaded to colab to train my model with GPU, you can find the validation loss below and the wandb logs under `wandb`

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PROJECT_PATH = '/content/drive/MyDrive/Colab\ Notebooks/Attention-is-all-you-need'

DRIVE_PYTHON_PATH = PROJECT_PATH.replace('\\', '')
if not os.path.exists(DRIVE_PYTHON_PATH):
  # %mkdir $DRIVE_PYTHON_PATH

## the space in `My Drive` causes some issues,
## make a symlink to avoid this
SYM_PATH = '/content/Attention'
if not os.path.exists(SYM_PATH):
  # !ln -s $PROJECT_PATH $SYM_PATH

# %cd $PROJECT_PATH
# Out:
# /content/drive/MyDrive/Colab Notebooks/Attention-is-all-you-need

# %%
# !git clone https://github.com/fadibenz/Attention-is-all-you-need
# Out:
# Cloning into 'Attention-is-all-you-need'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 28 (delta 0), reused 28 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 2.46 MiB | 24.68 MiB/s, done.

# %%
# %cd Attention-is-all-you-need
# Out:
# /content/drive/MyDrive/Colab Notebooks/Attention-is-all-you-need/Attention-is-all-you-need

# %%
# !pip install -r requirements.txt
# Out:
# Obtaining file:///content/drive/MyDrive/Colab%20Notebooks/Attention-is-all-you-need/Attention-is-all-you-need (from -r requirements.txt (line 3))
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 4.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 86.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 115.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.9 MB/s eta 0:00:00
# ...

# %%
# !python Attention_is_all_you_need/main.py
# Out:
# 2025-03-25 13:36:53.193670: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742909813.227719    4996 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742909813.238960    4996 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-25 13:36:53.273066: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## Conclusion
# The model was successfully trained to a validation loss of around 4.9, which is acceptable. The model is inefficient though when it comes to computation, I will add KV caching in the future.
